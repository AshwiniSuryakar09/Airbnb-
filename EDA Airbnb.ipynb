# %% [markdown]
# # **Project Name - Airbnb Bookings Analysis**
# ## **Project Type - Exploratory Data Analysis (EDA)**
# ## **Contribution - Individual**

# %% [markdown]
# # **Project Summary -**
# ### Airbnb has revolutionized the way people travel and experience new places by providing a unique and personalized alternative to traditional hotel stays. By connecting hosts who have extra space in their homes or apartments with travelers looking for a more authentic and local experience, Airbnb has created a thriving community of people from all over the world who are passionate about exploring new cultures and sharing their own.
#
# ### As Airbnb has grown in popularity, the company has also recognized the value of data analysis in understanding its customers and hosts, making informed business decisions, and identifying new opportunities for growth. With millions of listings on its platform, Airbnb generates a vast amount of data that can be used to gain insights into the behavior and performance of hosts and guests.
#
# ### This project aims to explore and analyze a dataset of approximately 49,000 Airbnb listings in order to gain a better understanding of the factors that drive success on the platform. The dataset includes both categorical and numeric variables, such as the location of the listing, the type of property, the price, the number of reviews, and the amenities offered.
#
# ### One of the key questions we can explore using this data is what sets successful hosts apart from those who may be struggling. By examining variables such as the number of bookings and reviews, the location of the listings, and the amenities offered, we can identify patterns and trends that may be correlated with higher levels of success.

# %% [markdown]
# ### In addition to studying the characteristics of individual hosts, we can also use the data to understand the factors that influence demand for Airbnb listings in different areas. Factors such as the availability of local attractions, the cost of living, and the overall quality of life in an area may all play a role in determining the popularity of Airbnb listings.
#
# ### Another area of interest for Airbnb is predicting future demand and pricing for its listings. By using machine learning techniques such as regression or classification, we can build models that can predict the likelihood of a listing being booked or the expected price based on factors such as the location, type of property, and amenities offered. These predictions can be valuable for both hosts and guests, as they can help hosts set competitive prices and guests make informed decisions about where to stay.
#
# ### Overall, the data generated by Airbnb's millions of listings provides a rich source of information that can be used to understand the behavior and preferences of hosts and guests, make informed business decisions, and identify new opportunities for growth and innovation. By exploring and analyzing this data, we can gain a deeper understanding of the factors that drive success on Airbnb and use this knowledge to drive the company's continued success.

# %% [markdown]
# ### Findings after exploratory data analysis:
#
# ### * Average price distribution for airbnb falls under the range of 1000 i.e., 150-200.
# ### * Amoung all different area Manhattan and Brooklyn has maximum airbnb and Staten Island has least airbnb.
# ### * Sounder is the most popular host with the highest number of airbnb listings.
# ### * Price which airbnb offer in Manhattan is more than others.
# ### * Airbnb listing Room near JFK Queen Bed has maximum number of reviews but when compared with average review per month airbnb listing - Enjoy great views of the City in our Deluxe Room! and host name Sonder and Entire home/apt shows maximum customer engagement.
# ### * Sonder can possibly produce highest revenue if booked for entire available day with minimum night booking.

# %% [markdown]
# ## Problem Statement -
# ### As Airbnb continues to expand and grow, it is important for the company to to use data analysis to gain insights into the behavior and performance of hosts and customers on the Airbnb platform, and to use this knowledge to inform business decisions and identify opportunities for growth and innovation. Specifically, the goal is to understand the factors that drive success on Airbnb, including the characteristics of successful hosts, the demand for listings in different locations, and the factors that influence pricing and demand. The goal is to explore data to predict factors such as demand, pricing, and the busiest hosts, and to identify areas where Airbnb can improve its services or expand its offerings. By understanding these factors, Airbnb can make informed decisions about how to optimize its platform and services to better meet the needs of its users and drive continued growth and success.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
Airbnb_df = pd.read_csv('/content/drive/MyDrive/listings.csv.gz')
Airbnb_df
# Out:
#                        id                                       listing_url  \
# 0                    2384                 https://www.airbnb.com/rooms/2384
# 1                    7126                 https://www.airbnb.com/rooms/7126
# 2                   10945                https://www.airbnb.com/rooms/10945
# 3                   12140                https://www.airbnb.com/rooms/12140
# 4                   24833                https://www.airbnb.com/rooms/24833
# ...                   ...                                               ...
# 7702  1116851419125146887  https://www.airbnb.com/rooms/1116851419125146887
# 7703  1117394712148132475  https://www.airbnb.com/rooms/1117394712148132475
# 7704  1117438873812832956  https://www.airbnb.com/rooms/1117438873812832956
# 7705  1117439997700638787  https://www.airbnb.com/rooms/1117439997700638787
# 7706  1117896281364781567  https://www.airbnb.com/rooms/1117896281364781567
#
#            scrape_id last_scraped       source  \
# 0     20240323200240   2024-03-23  city scrape
# 1     20240323200240   2024-03-24  city scrape
# 2     20240323200240   2024-03-24  city scrape
# 3     20240323200240   2024-03-24  city scrape
# 4     20240323200240   2024-03-24  city scrape
# ...              ...          ...          ...
# 7702  20240323200240   2024-03-24  city scrape
# 7703  20240323200240   2024-03-24  city scrape
# 7704  20240323200240   2024-03-24  city scrape
# 7705  20240323200240   2024-03-24  city scrape
# 7706  20240323200240   2024-03-24  city scrape
#
#                                                    name  \
# 0                          Hyde Park - Walk to UChicago
# 1                   Tiny Studio Apartment 94 Walk Score
# 2                                 The Biddle House (#1)
# 3                              Lincoln Park Guest House
# 4     Prime LincolnPark 1 Block Fullerton Express L ...
# ...                                                 ...
# 7702                   Stylish 2BR Retreat in Hyde Park
# 7703                    Vintage renovation in Logan Sq!
# 7704          Guest king Room at Aloft Chicago Mag Mile
# 7705       Guest 2 Queen Room at Aloft Chicago Mag Mile
# 7706                                    Cali king suite
#
#                                             description  \
# 0     You are invited stay in the guest room of my v...
# 1      A very small studio in a wonderful neighborhood.
# 2     Beautiful first floor apartment in Historic Ol...
# 3     Bed and Breakfast license issued by the City o...
# 4     Perfect private entrance apartment one block f...
# ...                                                 ...
# 7702  Welcome to our inviting 2-bedroom apartment si...
# 7703  Recent renovation! Tall ceilings, gorgeous woo...
# 7704  Welcome to Aloft Chicago Mag Mile <br /> <br /...
# 7705  Welcome to Aloft Chicago Mag Mile <br /> <br /...
# 7706  Your family will be close to everything when y...
#
#                                   neighborhood_overview  \
# 0     The apartment is less than one block from beau...
# 1     Ukrainian Village was just named "Hottest Neig...
# 2                                                   NaN
# 3     The Guest House is in the heart of Chicago's m...
# 4     Lincoln Park is a great neighborhood where peo...
# ...                                                 ...
# 7702  Hyde Park, located on Chicago's South Side, is...
# 7703                                                NaN
# 7704  ▶What's nearby <br />• In Downtown Chicago <br...
# 7705  ▶What's nearby <br />• In Downtown Chicago <br...
# 7706                                                NaN
#
#                                             picture_url    host_id  ...  \
# 0     https://a0.muscache.com/pictures/acf6b3c0-47f2...       2613  ...
# 1     https://a0.muscache.com/pictures/51073/16c81c7...      17928  ...
# 2     https://a0.muscache.com/pictures/58d1a420-a24b...      33004  ...
# 3     https://a0.muscache.com/pictures/miso/Hosting-...      46734  ...
# 4     https://a0.muscache.com/pictures/ac17be6f-40bd...     101521  ...
# ...                                                 ...        ...  ...
# 7702  https://a0.muscache.com/pictures/miso/Hosting-...  458971964  ...
# 7703  https://a0.muscache.com/pictures/miso/Hosting-...  442832620  ...
# 7704  https://a0.muscache.com/pictures/prohost-api/H...  468436552  ...
# 7705  https://a0.muscache.com/pictures/prohost-api/H...  468436552  ...
# 7706  https://a0.muscache.com/pictures/2fdb78f9-265d...   97416998  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 0                           4.98                   4.96                4.94
# 1                           4.87                   4.89                4.75
# 2                           4.84                   4.98                4.66
# 3                           5.00                   5.00                4.87
# 4                           4.03                   4.90                4.20
# ...                          ...                    ...                 ...
# 7702                         NaN                    NaN                 NaN
# 7703                         NaN                    NaN                 NaN
# 7704                         NaN                    NaN                 NaN
# 7705                         NaN                    NaN                 NaN
# 7706                         NaN                    NaN                 NaN
#
#                         license instant_bookable  \
# 0                  R17000015609                f
# 1                  R24000114046                f
# 2                       2209984                t
# 3                  R20000055258                f
# 4     City registration pending                f
# ...                         ...              ...
# 7702               R21000074744                t
# 7703                        NaN                f
# 7704               R65232147523                t
# 7705               R65232147523                t
# 7706               R21000075858                f
#
#      calculated_host_listings_count  \
# 0                                 1
# 1                                 1
# 2                                 6
# 3                                 1
# 4                                 4
# ...                             ...
# 7702                              7
# 7703                              1
# 7704                              2
# 7705                              2
# 7706                              5
#
#      calculated_host_listings_count_entire_homes  \
# 0                                              0
# 1                                              1
# 2                                              6
# 3                                              0
# 4                                              4
# ...                                          ...
# 7702                                           7
# 7703                                           1
# 7704                                           2
# 7705                                           2
# 7706                                           5
#
#      calculated_host_listings_count_private_rooms  \
# 0                                               1
# 1                                               0
# 2                                               0
# 3                                               1
# 4                                               0
# ...                                           ...
# 7702                                            0
# 7703                                            0
# 7704                                            0
# 7705                                            0
# 7706                                            0
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                              0              2.09
# 1                                              0              2.88
# 2                                              0              0.69
# 3                                              0              0.14
# 4                                              0              0.24
# ...                                          ...               ...
# 7702                                           0               NaN
# 7703                                           0               NaN
# 7704                                           0               NaN
# 7705                                           0               NaN
# 7706                                           0               NaN
#
# [7707 rows x 75 columns]

# %% [markdown]
# # **About the Dataset :**
# ## **Airbnb Bookings**
#
# This Airbnb dataset contains nearly 7700 observations from , with 75 columns of data.
#
# The Data includes both categorical and numeric values, providing a diverse range of information about the listings.
#
# This Dataset may be useful for analyzing trends and patterns in the Airbnb market in New York and also gain insights into the preferences and behavior of Airbnb users in the area.
#
# This dataset contains information about Airbnb data of Chicago city. By analyzing this data, you may be able to understand the trends and patterns of Airbnb use in the Chicago.

# %% [markdown]
# ## **UNDERSTAND THE GIVEN VARIABLES**
#
# id :- This is a unique identifier for each listing in the dataset.
#
# name :- This is the name or title of the listing, as it appears on the Airbnb website.
#
# Host_id :- This is a unique identifier for each host in the dataset.
#
# Host_name :- This is the name of the host as it appears on the Airbnb website.
#
# Neighbourhood_group :- This is a grouping of neighborhoods in New York City, such as Manhattan or Brooklyn.
#
# Neighbourhood :- This is the specific neighborhood in which the listing is located.
#
# Latitude :- This is the geographic latitude of the listing.
#
# Longitude :- This is the geographic longitude of the listing.
#
# Room_type :- This is the type of room or property being offered, such as an entire home, private room, shared room.
#
# Price :- This is the nightly price for the listing, in US dollars.
#
# Minimum_nights :- This is the minimum number of nights that a guest must stay at the listing.
#
# Total_reviews :- This is the total number of reviews that the listing has received.
#
# Reviews_per_month :- This is the average number of reviews that the listing receives per month.
#
# Host_listings_count :- This is the total number of listings that the host has on Airbnb.
#
# Availability_365 :- This is the number of days in the next 365 days that the listing is available for booking.

# %%
Airbnb_df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   2384   https://www.airbnb.com/rooms/2384  20240323200240   2024-03-23
# 1   7126   https://www.airbnb.com/rooms/7126  20240323200240   2024-03-24
# 2  10945  https://www.airbnb.com/rooms/10945  20240323200240   2024-03-24
# 3  12140  https://www.airbnb.com/rooms/12140  20240323200240   2024-03-24
# 4  24833  https://www.airbnb.com/rooms/24833  20240323200240   2024-03-24
#
#         source                                               name  \
# 0  city scrape                       Hyde Park - Walk to UChicago
# 1  city scrape                Tiny Studio Apartment 94 Walk Score
# 2  city scrape                              The Biddle House (#1)
# 3  city scrape                           Lincoln Park Guest House
# 4  city scrape  Prime LincolnPark 1 Block Fullerton Express L ...
#
#                                          description  \
# 0  You are invited stay in the guest room of my v...
# 1   A very small studio in a wonderful neighborhood.
# 2  Beautiful first floor apartment in Historic Ol...
# 3  Bed and Breakfast license issued by the City o...
# 4  Perfect private entrance apartment one block f...
#
#                                neighborhood_overview  \
# 0  The apartment is less than one block from beau...
# 1  Ukrainian Village was just named "Hottest Neig...
# 2                                                NaN
# 3  The Guest House is in the heart of Chicago's m...
# 4  Lincoln Park is a great neighborhood where peo...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/acf6b3c0-47f2...     2613  ...
# 1  https://a0.muscache.com/pictures/51073/16c81c7...    17928  ...
# 2  https://a0.muscache.com/pictures/58d1a420-a24b...    33004  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...    46734  ...
# 4  https://a0.muscache.com/pictures/ac17be6f-40bd...   101521  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.98                   4.96                4.94
# 1                        4.87                   4.89                4.75
# 2                        4.84                   4.98                4.66
# 3                        5.00                   5.00                4.87
# 4                        4.03                   4.90                4.20
#
#                      license instant_bookable calculated_host_listings_count  \
# 0               R17000015609                f                              1
# 1               R24000114046                f                              1
# 2                    2209984                t                              6
# 3               R20000055258                f                              1
# 4  City registration pending                f                              4
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
# 2                                           6
# 3                                           0
# 4                                           4
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            1
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.09
# 1                                           0              2.88
# 2                                           0              0.69
# 3                                           0              0.14
# 4                                           0              0.24
#
# [5 rows x 75 columns]

# %%
Airbnb_df.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'license', 'instant_bookable',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month'],
#       dtype='object')

# %%
print(f'Shape: {Airbnb_df.shape}')
# Out:
# Shape: (7707, 75)

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7707 entries, 0 to 7706
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            7707 non-null   int64
#  1   listing_url                                   7707 non-null   object
#  2   scrape_id                                     7707 non-null   int64
#  3   last_scraped                                  7707 non-null   object
#  4   source                                        7707 non-null   object
#  5   name                                          7707 non-null   object
#  6   description                                   7622 non-null   object
#  7   neighborhood_overview                         5428 non-null   object
#  8   picture_url                                   7707 non-null   object
#  9   host_id                                       7707 non-null   int64
#  10  host_url                                      7707 non-null   object
#  11  host_name                                     7707 non-null   object
#  12  host_since                                    7707 non-null   object
#  13  host_location                                 6288 non-null   object
#  14  host_about                                    5238 non-null   object
#  15  host_response_time                            7213 non-null   object
#  16  host_response_rate                            7213 non-null   object
#  17  host_acceptance_rate                          7377 non-null   object
#  18  host_is_superhost                             7639 non-null   object
#  19  host_thumbnail_url                            7707 non-null   object
#  20  host_picture_url                              7707 non-null   object
#  21  host_neighbourhood                            7504 non-null   object
#  22  host_listings_count                           7707 non-null   int64
#  23  host_total_listings_count                     7707 non-null   int64
#  24  host_verifications                            7707 non-null   object
#  25  host_has_profile_pic                          7707 non-null   object
#  26  host_identity_verified                        7707 non-null   object
#  27  neighbourhood                                 5429 non-null   object
#  28  neighbourhood_cleansed                        7707 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      7707 non-null   float64
#  31  longitude                                     7707 non-null   float64
#  32  property_type                                 7707 non-null   object
#  33  room_type                                     7707 non-null   object
#  34  accommodates                                  7707 non-null   int64
#  35  bathrooms                                     7521 non-null   float64
#  36  bathrooms_text                                7696 non-null   object
#  37  bedrooms                                      7664 non-null   float64
#  38  beds                                          7494 non-null   float64
#  39  amenities                                     7707 non-null   object
#  40  price                                         7522 non-null   object
#  41  minimum_nights                                7707 non-null   int64
#  42  maximum_nights                                7707 non-null   int64
#  43  minimum_minimum_nights                        7707 non-null   int64
#  44  maximum_minimum_nights                        7707 non-null   int64
#  45  minimum_maximum_nights                        7707 non-null   int64
#  46  maximum_maximum_nights                        7707 non-null   int64
#  47  minimum_nights_avg_ntm                        7707 non-null   float64
#  48  maximum_nights_avg_ntm                        7707 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              7671 non-null   object
#  51  availability_30                               7707 non-null   int64
#  52  availability_60                               7707 non-null   int64
#  53  availability_90                               7707 non-null   int64
#  54  availability_365                              7707 non-null   int64
#  55  calendar_last_scraped                         7707 non-null   object
#  56  number_of_reviews                             7707 non-null   int64
#  57  number_of_reviews_ltm                         7707 non-null   int64
#  58  number_of_reviews_l30d                        7707 non-null   int64
#  59  first_review                                  6152 non-null   object
#  60  last_review                                   6152 non-null   object
#  61  review_scores_rating                          6152 non-null   float64
#  62  review_scores_accuracy                        6144 non-null   float64
#  63  review_scores_cleanliness                     6143 non-null   float64
#  64  review_scores_checkin                         6144 non-null   float64
#  65  review_scores_communication                   6144 non-null   float64
#  66  review_scores_location                        6144 non-null   float64
#  67  review_scores_value                           6144 non-null   float64
#  68  license                                       6247 non-null   object
#  69  instant_bookable                              7707 non-null   object
#  70  calculated_host_listings_count                7707 non-null   int64
#  71  calculated_host_listings_count_entire_homes   7707 non-null   int64
#  72  calculated_host_listings_count_private_rooms  7707 non-null   int64
#  73  calculated_host_listings_count_shared_rooms   7707 non-null   int64
#  74  reviews_per_month                             6152 non-null   float64
# dtypes: float64(17), int64(23), object(35)
# memory usage: 4.4+ MB

# %%
# Dataset Duplicate Value Count
# airbnb_df.duplicated().value_counts()
len(Airbnb_df[Airbnb_df.duplicated()])
# Out:
# 0

# %%
Airbnb_df = Airbnb_df.drop_duplicates()
Airbnb_df.count()
# Out:
# id                                              7707
# listing_url                                     7707
# scrape_id                                       7707
# last_scraped                                    7707
# source                                          7707
#                                                 ...
# calculated_host_listings_count                  7707
# calculated_host_listings_count_entire_homes     7707
# calculated_host_listings_count_private_rooms    7707
# calculated_host_listings_count_shared_rooms     7707
# reviews_per_month                               6152
# Length: 75, dtype: int64

# %%
# checking null values of each columns
Airbnb_df.isnull().sum()
# Out:
# id                                                 0
# listing_url                                        0
# scrape_id                                          0
# last_scraped                                       0
# source                                             0
#                                                 ...
# calculated_host_listings_count                     0
# calculated_host_listings_count_entire_homes        0
# calculated_host_listings_count_private_rooms       0
# calculated_host_listings_count_shared_rooms        0
# reviews_per_month                               1555
# Length: 75, dtype: int64

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(Airbnb_df.isnull(), cbar=False);

# %%
#this will return column with atleast one null value
Airbnb_df.loc[:,Airbnb_df.isna().sum()!=0][:5]
# Out:
#                                          description  \
# 0  You are invited stay in the guest room of my v...
# 1   A very small studio in a wonderful neighborhood.
# 2  Beautiful first floor apartment in Historic Ol...
# 3  Bed and Breakfast license issued by the City o...
# 4  Perfect private entrance apartment one block f...
#
#                                neighborhood_overview host_location  \
# 0  The apartment is less than one block from beau...   Chicago, IL
# 1  Ukrainian Village was just named "Hottest Neig...   Chicago, IL
# 2                                                NaN   Chicago, IL
# 3  The Guest House is in the heart of Chicago's m...   Chicago, IL
# 4  Lincoln Park is a great neighborhood where peo...   Chicago, IL
#
#                                           host_about  host_response_time  \
# 0  My apartment is a 2nd floor walk-up in a centu...      within an hour
# 1  We live in Chicago. We love to travel and see ...      within an hour
# 2  Hi, we're Bob and Liz Biddle, long time Chicag...      within an hour
# 3  Best in the city with long-time urban-dwelling...        within a day
# 4  Travel is fun and exciting but can be hard on ...  within a few hours
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0               100%                  91%                 t
# 1               100%                 100%                 t
# 2                97%                  93%                 t
# 3               100%                 100%                 f
# 4               100%                  85%                 t
#
#   host_neighbourhood                     neighbourhood  ...  last_review  \
# 0          Hyde Park  Chicago, Illinois, United States  ...   2024-03-12
# 1  Ukrainian Village  Chicago, Illinois, United States  ...   2024-03-03
# 2           Old Town                               NaN  ...   2024-03-06
# 3       Lincoln Park  Chicago, Illinois, United States  ...   2023-05-21
# 4       Lincoln Park  Chicago, Illinois, United States  ...   2023-04-22
#
#    review_scores_rating review_scores_accuracy  review_scores_cleanliness  \
# 0                  4.99                   4.98                       4.99
# 1                  4.70                   4.85                       4.56
# 2                  4.65                   4.80                       4.80
# 3                  4.93                   4.67                       5.00
# 4                  4.29                   4.07                       4.00
#
#    review_scores_checkin review_scores_communication  review_scores_location  \
# 0                   4.99                        4.98                    4.96
# 1                   4.90                        4.87                    4.89
# 2                   4.80                        4.84                    4.98
# 3                   5.00                        5.00                    5.00
# 4                   4.13                        4.03                    4.90
#
#   review_scores_value                    license reviews_per_month
# 0                4.94               R17000015609              2.09
# 1                4.75               R24000114046              2.88
# 2                4.66                    2209984              0.69
# 3                4.87               R20000055258              0.14
# 4                4.20  City registration pending              0.24
#
# [5 rows x 29 columns]

# %%
# Missing Value Count Function
def showMissing():
    missing = Airbnb_df.columns[Airbnb_df.isnull().any()].tolist()
    return missing

missingVal = pd.DataFrame()
missingVal['Missing Data Count'] = Airbnb_df[showMissing()].isnull().sum().sort_values(ascending = False)
missingVal['Missing Data Percentage'] = Airbnb_df[showMissing()].isnull().sum().sort_values(ascending = False)/len(Airbnb_df)*100

print(missingVal)
# Out:
#                               Missing Data Count  Missing Data Percentage
# neighbourhood_group_cleansed                7707               100.000000
# calendar_updated                            7707               100.000000
# host_about                                  2469                32.035812
# neighborhood_overview                       2279                29.570520
# neighbourhood                               2278                29.557545
# review_scores_cleanliness                   1564                20.293240
# review_scores_communication                 1563                20.280265
# review_scores_accuracy                      1563                20.280265
# review_scores_value                         1563                20.280265
# review_scores_checkin                       1563                20.280265
# review_scores_location                      1563                20.280265
# first_review                                1555                20.176463
# reviews_per_month                           1555                20.176463
# review_scores_rating                        1555                20.176463
# last_review                                 1555                20.176463
# license                                     1460                18.943817
# host_location                               1419                18.411833
# host_response_rate                           494                 6.409757
# host_response_time                           494                 6.409757
# host_acceptance_rate                         330                 4.281822
# beds                                         213                 2.763721
# host_neighbourhood                           203                 2.633969
# bathrooms                                    186                 2.413390
# price                                        185                 2.400415
# description                                   85                 1.102893
# host_is_superhost                             68                 0.882315
# bedrooms                                      43                 0.557934
# has_availability                              36                 0.467108
# bathrooms_text                                11                 0.142727

# %%
rename_col = {'id':'listing_id','name':'listing_name','number_of_reviews':'total_reviews','calculated_host_listings_count':'host_listings_count'}

# %%
# use a pandas function to rename the current function
Airbnb_df = Airbnb_df.rename(columns = rename_col)
Airbnb_df.head(2)
# Out:
#    listing_id                        listing_url       scrape_id last_scraped  \
# 0        2384  https://www.airbnb.com/rooms/2384  20240323200240   2024-03-23
# 1        7126  https://www.airbnb.com/rooms/7126  20240323200240   2024-03-24
#
#         source                         listing_name  \
# 0  city scrape         Hyde Park - Walk to UChicago
# 1  city scrape  Tiny Studio Apartment 94 Walk Score
#
#                                          description  \
# 0  You are invited stay in the guest room of my v...
# 1   A very small studio in a wonderful neighborhood.
#
#                                neighborhood_overview  \
# 0  The apartment is less than one block from beau...
# 1  Ukrainian Village was just named "Hottest Neig...
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/acf6b3c0-47f2...     2613  ...
# 1  https://a0.muscache.com/pictures/51073/16c81c7...    17928  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.98                   4.96                4.94
# 1                        4.87                   4.89                4.75
#
#         license instant_bookable host_listings_count  \
# 0  R17000015609                f                   1
# 1  R24000114046                f                   1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              2.09
# 1                                           0              2.88
#
# [2 rows x 75 columns]

# %%
Airbnb_df['listing_name'].fillna('unknown',inplace=True)
Airbnb_df['host_name'].fillna('no_name',inplace=True)

# %%
Airbnb_df[['host_name','listing_name']].isnull().sum()
# Out:
# host_name       0
# listing_name    0
# dtype: int64

# %%
if 'last_review' in Airbnb_df.columns:
    # Drop the column if it exists
    Airbnb_df = Airbnb_df.drop(['last_review'], axis=1)
else:
    print("Column 'last_review' not found in the DataFrame")

# %%
Airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7707 entries, 0 to 7706
# Data columns (total 74 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   listing_id                                    7707 non-null   int64
#  1   listing_url                                   7707 non-null   object
#  2   scrape_id                                     7707 non-null   int64
#  3   last_scraped                                  7707 non-null   object
#  4   source                                        7707 non-null   object
#  5   listing_name                                  7707 non-null   object
#  6   description                                   7622 non-null   object
#  7   neighborhood_overview                         5428 non-null   object
#  8   picture_url                                   7707 non-null   object
#  9   host_id                                       7707 non-null   int64
#  10  host_url                                      7707 non-null   object
#  11  host_name                                     7707 non-null   object
#  12  host_since                                    7707 non-null   object
#  13  host_location                                 6288 non-null   object
#  14  host_about                                    5238 non-null   object
#  15  host_response_time                            7213 non-null   object
#  16  host_response_rate                            7213 non-null   object
#  17  host_acceptance_rate                          7377 non-null   object
#  18  host_is_superhost                             7639 non-null   object
#  19  host_thumbnail_url                            7707 non-null   object
#  20  host_picture_url                              7707 non-null   object
#  21  host_neighbourhood                            7504 non-null   object
#  22  host_listings_count                           7707 non-null   int64
#  23  host_total_listings_count                     7707 non-null   int64
#  24  host_verifications                            7707 non-null   object
#  25  host_has_profile_pic                          7707 non-null   object
#  26  host_identity_verified                        7707 non-null   object
#  27  neighbourhood                                 5429 non-null   object
#  28  neighbourhood_cleansed                        7707 non-null   object
#  29  neighbourhood_group_cleansed                  0 non-null      float64
#  30  latitude                                      7707 non-null   float64
#  31  longitude                                     7707 non-null   float64
#  32  property_type                                 7707 non-null   object
#  33  room_type                                     7707 non-null   object
#  34  accommodates                                  7707 non-null   int64
#  35  bathrooms                                     7521 non-null   float64
#  36  bathrooms_text                                7696 non-null   object
#  37  bedrooms                                      7664 non-null   float64
#  38  beds                                          7494 non-null   float64
#  39  amenities                                     7707 non-null   object
#  40  price                                         7522 non-null   object
#  41  minimum_nights                                7707 non-null   int64
#  42  maximum_nights                                7707 non-null   int64
#  43  minimum_minimum_nights                        7707 non-null   int64
#  44  maximum_minimum_nights                        7707 non-null   int64
#  45  minimum_maximum_nights                        7707 non-null   int64
#  46  maximum_maximum_nights                        7707 non-null   int64
#  47  minimum_nights_avg_ntm                        7707 non-null   float64
#  48  maximum_nights_avg_ntm                        7707 non-null   float64
#  49  calendar_updated                              0 non-null      float64
#  50  has_availability                              7671 non-null   object
#  51  availability_30                               7707 non-null   int64
#  52  availability_60                               7707 non-null   int64
#  53  availability_90                               7707 non-null   int64
#  54  availability_365                              7707 non-null   int64
#  55  calendar_last_scraped                         7707 non-null   object
#  56  total_reviews                                 7707 non-null   int64
#  57  number_of_reviews_ltm                         7707 non-null   int64
#  58  number_of_reviews_l30d                        7707 non-null   int64
#  59  first_review                                  6152 non-null   object
#  60  review_scores_rating                          6152 non-null   float64
#  61  review_scores_accuracy                        6144 non-null   float64
#  62  review_scores_cleanliness                     6143 non-null   float64
#  63  review_scores_checkin                         6144 non-null   float64
#  64  review_scores_communication                   6144 non-null   float64
#  65  review_scores_location                        6144 non-null   float64
#  66  review_scores_value                           6144 non-null   float64
#  67  license                                       6247 non-null   object
#  68  instant_bookable                              7707 non-null   object
#  69  host_listings_count                           7707 non-null   int64
#  70  calculated_host_listings_count_entire_homes   7707 non-null   int64
#  71  calculated_host_listings_count_private_rooms  7707 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   7707 non-null   int64
#  73  reviews_per_month                             6152 non-null   float64
# dtypes: float64(17), int64(23), object(34)
# memory usage: 4.4+ MB

# %%
Airbnb_df['reviews_per_month'] = Airbnb_df['reviews_per_month'].replace(to_replace=np.nan,value=0).astype('int64')

# %%
# the null values are replaced by 0 value
Airbnb_df['reviews_per_month'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### so there is no null value now in 'reviews_per_month' column because we replaced null value by 0 value. this will make sense because there is no any such data to find those null value

# %%
#so now check Dataset columns changed and null values, last_review column removed.
Airbnb_df.sample(5)
# Out:
#                listing_id                                       listing_url  \
# 4813   765378899319829745   https://www.airbnb.com/rooms/765378899319829745
# 1313             30594135             https://www.airbnb.com/rooms/30594135
# 6861  1020115215865200343  https://www.airbnb.com/rooms/1020115215865200343
# 2382             46414655             https://www.airbnb.com/rooms/46414655
# 7093  1043747210042281391  https://www.airbnb.com/rooms/1043747210042281391
#
#            scrape_id last_scraped       source  \
# 4813  20240323200240   2024-03-24  city scrape
# 1313  20240323200240   2024-03-23  city scrape
# 6861  20240323200240   2024-03-24  city scrape
# 2382  20240323200240   2024-03-24  city scrape
# 7093  20240323200240   2024-03-24  city scrape
#
#                                            listing_name  \
# 4813                                   Logan Square Gem
# 1313  Entire Spacious, Private Loft Apt Historic Bev...
# 6861                     1 Bd/Ba apt on Argyle St (302)
# 2382  Great Location! Next to Wrigley & Transit - Cubs!
# 7093                 Light-flooded rooms and city views
#
#                                             description  \
# 4813  Forget your worries in this spacious and seren...
# 1313  You have the loft suite to yourself.  Best for...
# 6861  In the middle of Argyle st., surrounded by a l...
# 2382  *New Flooring in living & Dining rm 2022 <br /...
# 7093  - This hip London-based brand transformed 3 me...
#
#                                   neighborhood_overview  \
# 4813  Great Neighborhood walk to cafes, restaurants,...
# 1313  Beverly is famous because it is incredibly saf...
# 6861  The community is pretty diverse.  But it is pa...
# 2382  Craving some coffee and breakfast? Dunkin Donu...
# 7093                                                NaN
#
#                                             picture_url    host_id  ...  \
# 4813  https://a0.muscache.com/pictures/b690eb79-52ff...  239108696  ...
# 1313  https://a0.muscache.com/pictures/miso/Hosting-...  229492288  ...
# 6861  https://a0.muscache.com/pictures/bc5fc163-11ec...  109077540  ...
# 2382  https://a0.muscache.com/pictures/miso/Hosting-...  375544374  ...
# 7093  https://a0.muscache.com/pictures/prohost-api/H...  546940547  ...
#
#      review_scores_communication review_scores_location review_scores_value  \
# 4813                        5.00                   5.00                4.71
# 1313                        4.96                   4.89                4.94
# 6861                        5.00                   5.00                5.00
# 2382                        4.84                   4.85                4.57
# 7093                        4.00                   5.00                4.75
#
#            license instant_bookable host_listings_count  \
# 4813  R22000095436                f                   1
# 1313  R23000110219                f                   1
# 6861  R23000095462                t                   3
# 2382  R21000076109                f                   2
# 7093       2627744                t                   3
#
#      calculated_host_listings_count_entire_homes  \
# 4813                                           1
# 1313                                           1
# 6861                                           3
# 2382                                           2
# 7093                                           0
#
#      calculated_host_listings_count_private_rooms  \
# 4813                                            0
# 1313                                            0
# 6861                                            0
# 2382                                            0
# 7093                                            3
#
#      calculated_host_listings_count_shared_rooms reviews_per_month
# 4813                                           0                 0
# 1313                                           0                 2
# 6861                                           0                 0
# 2382                                           0                 2
# 7093                                           0                 1
#
# [5 rows x 74 columns]

# %% [markdown]
# ## **Check Unique Value for variables and doing some experiments -**

# %%
# Check Unique Values for each variable.
# airbnb_df.nunique()
for i in Airbnb_df.columns.tolist():
  print(f"No. of unique values in {i} is {Airbnb_df[i].nunique()}.")
# Out:
# No. of unique values in listing_id is 7707.
# No. of unique values in listing_url is 7707.
# No. of unique values in scrape_id is 1.
# No. of unique values in last_scraped is 2.
# No. of unique values in source is 2.
# No. of unique values in listing_name is 7229.
# No. of unique values in description is 6446.
# No. of unique values in neighborhood_overview is 3586.
# No. of unique values in picture_url is 7387.
# No. of unique values in host_id is 3351.
# No. of unique values in host_url is 3351.
# No. of unique values in host_name is 1937.
# No. of unique values in host_since is 2276.
# No. of unique values in host_location is 209.
# No. of unique values in host_about is 1878.
# No. of unique values in host_response_time is 4.
# No. of unique values in host_response_rate is 49.
# No. of unique values in host_acceptance_rate is 77.
# No. of unique values in host_is_superhost is 2.
# No. of unique values in host_thumbnail_url is 3261.
# No. of unique values in host_picture_url is 3261.
# No. of unique values in host_neighbourhood is 222.
# No. of unique values in host_listings_count is host_listings_count    62
# host_listings_count    39
# dtype: int64.
# No. of unique values in host_total_listings_count is 86.
# No. of unique values in host_verifications is 7.
# No. of unique values in host_has_profile_pic is 2.
# No. of unique values in host_identity_verified is 2.
# No. of unique values in neighbourhood is 9.
# No. of unique values in neighbourhood_cleansed is 77.
# No. of unique values in neighbourhood_group_cleansed is 0.
# No. of unique values in latitude is 6456.
# No. of unique values in longitude is 6267.
# No. of unique values in property_type is 48.
# No. of unique values in room_type is 4.
# No. of unique values in accommodates is 16.
# No. of unique values in bathrooms is 23.
# No. of unique values in bathrooms_text is 35.
# No. of unique values in bedrooms is 13.
# No. of unique values in beds is 20.
# No. of unique values in amenities is 6902.
# No. of unique values in price is 608.
# No. of unique values in minimum_nights is 48.
# No. of unique values in maximum_nights is 130.
# No. of unique values in minimum_minimum_nights is 50.
# No. of unique values in maximum_minimum_nights is 58.
# No. of unique values in minimum_maximum_nights is 114.
# No. of unique values in maximum_maximum_nights is 127.
# No. of unique values in minimum_nights_avg_ntm is 226.
# No. of unique values in maximum_nights_avg_ntm is 374.
# No. of unique values in calendar_updated is 0.
# No. of unique values in has_availability is 2.
# No. of unique values in availability_30 is 31.
# No. of unique values in availability_60 is 61.
# No. of unique values in availability_90 is 91.
# No. of unique values in availability_365 is 366.
# No. of unique values in calendar_last_scraped is 2.
# No. of unique values in total_reviews is 425.
# No. of unique values in number_of_reviews_ltm is 121.
# No. of unique values in number_of_reviews_l30d is 24.
# No. of unique values in first_review is 2197.
# No. of unique values in review_scores_rating is 119.
# No. of unique values in review_scores_accuracy is 112.
# No. of unique values in review_scores_cleanliness is 130.
# No. of unique values in review_scores_checkin is 98.
# No. of unique values in review_scores_communication is 96.
# No. of unique values in review_scores_location is 153.
# No. of unique values in review_scores_value is 127.
# No. of unique values in license is 3974.
# No. of unique values in instant_bookable is 2.
# No. of unique values in host_listings_count is host_listings_count    62
# host_listings_count    39
# dtype: int64.
# No. of unique values in calculated_host_listings_count_entire_homes is 38.
# No. of unique values in calculated_host_listings_count_private_rooms is 23.
# No. of unique values in calculated_host_listings_count_shared_rooms is 8.
# No. of unique values in reviews_per_month is 25.

# %%
# check unique values for listing/property Ids
# all the listing ids are different and each listings are different here.
Airbnb_df['listing_id'].nunique()
# Out:
# 7707

# %%
# so there are 9 unique neighborhood in Dataset
Airbnb_df['neighbourhood'].nunique()
# Out:
# 9

# %%
Airbnb_df['neighbourhood'].nunique()
# Out:
# 9

# %%
#so total 1937 different hosts in Airbnb
Airbnb_df['host_name'].nunique()
# Out:
# 1937

# %%
# most of the listing/property are different in Dataset
Airbnb_df['listing_name'].nunique()
# Out:
# 7229

# %%
Airbnb_df[Airbnb_df['host_name']=='David']['listing_name'].nunique()

# so here same host David operates different 402 listing/property
# Out:
# 61

# %% [markdown]
# # **Describe the Dataset and removing outliers**

# %%
# Dataset Columns
print(f'Features : {Airbnb_df.columns.to_list()}')
# Out:
# Features : ['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'listing_name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'total_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'license', 'instant_bookable', 'host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
# describe the DataFrame
Airbnb_df.describe()
# Out:
#          listing_id     scrape_id       host_id  host_listings_count  \
# count  7.707000e+03  7.707000e+03  7.707000e+03          7707.000000
# mean   4.798164e+17  2.024032e+13  1.948637e+08           384.492020
# std    4.434928e+17  3.906503e-03  1.770821e+08          1277.307206
# min    2.384000e+03  2.024032e+13  2.153000e+03             1.000000
# 25%    4.073590e+07  2.024032e+13  3.851769e+07             1.000000
# 50%    6.279558e+17  2.024032e+13  1.217199e+08             5.000000
# 75%    9.067312e+17  2.024032e+13  3.701546e+08            21.000000
# max    1.117896e+18  2.024032e+13  5.679786e+08          4914.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                7707.000000                           0.0  7707.000000
# mean                  432.263008                           NaN    41.891764
# std                  1405.012522                           NaN     0.063333
# min                     1.000000                           NaN    41.646767
# 25%                     2.000000                           NaN    41.858758
# 50%                     6.000000                           NaN    41.896218
# 75%                    28.000000                           NaN    41.935954
# max                  8920.000000                           NaN    42.022200
#
#          longitude  accommodates    bathrooms  ...  review_scores_cleanliness  \
# count  7707.000000   7707.000000  7521.000000  ...                6143.000000
# mean    -87.662794      4.390684     1.422949  ...                   4.768161
# std       0.043779      3.036858     0.814847  ...                   0.376400
# min     -87.846720      1.000000     0.000000  ...                   1.000000
# 25%     -87.685815      2.000000     1.000000  ...                   4.710000
# 50%     -87.658708      4.000000     1.000000  ...                   4.870000
# 75%     -87.631722      6.000000     2.000000  ...                   4.990000
# max     -87.528420     16.000000    20.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            6144.000000                  6144.000000
# mean                4.850627                     4.867183
# std                 0.308851                     0.314325
# min                 1.000000                     1.000000
# 25%                 4.830000                     4.867500
# 50%                 4.940000                     4.960000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  host_listings_count  \
# count             6144.000000          6144.000000          7707.000000
# mean                 4.766558             4.697645            49.256650
# std                  0.354800             0.388641           141.704968
# min                  1.000000             1.000000             1.000000
# 25%                  4.710000             4.630000             1.000000
# 50%                  4.880000             4.790000             4.000000
# 75%                  4.980000             4.900000            17.000000
# max                  5.000000             5.000000           555.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7707.000000
# mean                                     46.540158
# std                                     142.265695
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       9.000000
# max                                     555.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7707.000000
# mean                                       2.547035
# std                                        9.009192
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       65.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  7707.000000        7707.000000
# mean                                      0.109511           1.120021
# std                                       1.174363           1.932684
# min                                       0.000000           0.000000
# 25%                                       0.000000           0.000000
# 50%                                       0.000000           1.000000
# 75%                                       0.000000           2.000000
# max                                      20.000000          57.000000
#
# [8 rows x 40 columns]

# %%
sns.boxplot(x = Airbnb_df['price'])

plt.show()

# %% [markdown]
# # **Data Visualization**

# %%
# Dataset Columns
print(f'Features : {Airbnb_df.columns.to_list()}')
# Out:
# Features : ['listing_id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'listing_name', 'description', 'neighborhood_overview', 'picture_url', 'host_id', 'host_url', 'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 'host_acceptance_rate', 'host_is_superhost', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude', 'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms', 'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights', 'maximum_nights', 'minimum_minimum_nights', 'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60', 'availability_90', 'availability_365', 'calendar_last_scraped', 'total_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d', 'first_review', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'license', 'instant_bookable', 'host_listings_count', 'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 'calculated_host_listings_count_shared_rooms', 'reviews_per_month']

# %%
# Dataset Describe
Airbnb_df.describe()
# Out:
#          listing_id     scrape_id       host_id  host_listings_count  \
# count  7.707000e+03  7.707000e+03  7.707000e+03          7707.000000
# mean   4.798164e+17  2.024032e+13  1.948637e+08           384.492020
# std    4.434928e+17  3.906503e-03  1.770821e+08          1277.307206
# min    2.384000e+03  2.024032e+13  2.153000e+03             1.000000
# 25%    4.073590e+07  2.024032e+13  3.851769e+07             1.000000
# 50%    6.279558e+17  2.024032e+13  1.217199e+08             5.000000
# 75%    9.067312e+17  2.024032e+13  3.701546e+08            21.000000
# max    1.117896e+18  2.024032e+13  5.679786e+08          4914.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                7707.000000                           0.0  7707.000000
# mean                  432.263008                           NaN    41.891764
# std                  1405.012522                           NaN     0.063333
# min                     1.000000                           NaN    41.646767
# 25%                     2.000000                           NaN    41.858758
# 50%                     6.000000                           NaN    41.896218
# 75%                    28.000000                           NaN    41.935954
# max                  8920.000000                           NaN    42.022200
#
#          longitude  accommodates    bathrooms  ...  review_scores_cleanliness  \
# count  7707.000000   7707.000000  7521.000000  ...                6143.000000
# mean    -87.662794      4.390684     1.422949  ...                   4.768161
# std       0.043779      3.036858     0.814847  ...                   0.376400
# min     -87.846720      1.000000     0.000000  ...                   1.000000
# 25%     -87.685815      2.000000     1.000000  ...                   4.710000
# 50%     -87.658708      4.000000     1.000000  ...                   4.870000
# 75%     -87.631722      6.000000     2.000000  ...                   4.990000
# max     -87.528420     16.000000    20.000000  ...                   5.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            6144.000000                  6144.000000
# mean                4.850627                     4.867183
# std                 0.308851                     0.314325
# min                 1.000000                     1.000000
# 25%                 4.830000                     4.867500
# 50%                 4.940000                     4.960000
# 75%                 5.000000                     5.000000
# max                 5.000000                     5.000000
#
#        review_scores_location  review_scores_value  host_listings_count  \
# count             6144.000000          6144.000000          7707.000000
# mean                 4.766558             4.697645            49.256650
# std                  0.354800             0.388641           141.704968
# min                  1.000000             1.000000             1.000000
# 25%                  4.710000             4.630000             1.000000
# 50%                  4.880000             4.790000             4.000000
# 75%                  4.980000             4.900000            17.000000
# max                  5.000000             5.000000           555.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  7707.000000
# mean                                     46.540158
# std                                     142.265695
# min                                       0.000000
# 25%                                       1.000000
# 50%                                       2.000000
# 75%                                       9.000000
# max                                     555.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   7707.000000
# mean                                       2.547035
# std                                        9.009192
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        1.000000
# max                                       65.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  7707.000000        7707.000000
# mean                                      0.109511           1.120021
# std                                       1.174363           1.932684
# min                                       0.000000           0.000000
# 25%                                       0.000000           0.000000
# 50%                                       0.000000           1.000000
# 75%                                       0.000000           2.000000
# max                                      20.000000          57.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# ## **(1) Distribution Of Airbnb Bookings Price Range Using Histogram**

# %%
# Visualizing the missing values
# Checking Null Value by plotting Heatmap
sns.heatmap(Airbnb_df.isnull(), cbar=False);

# %% [markdown]
# # **Variables Description**
# * id : Unique Id generated while storing data
# * name : Name of the listing
# * host_id : The host id is assigned to each host by Airbnb and is used to identify and distinguish hosts from one another.
# * host_name : The host name is typically the name of the person who owns the property or is authorized to list it on Airbnb.
# * neighbourhood_group : Location of the listing / categorical variable that indicates the general geographic area in which a listing is located.
# * neighbourhood : area of the listing
# * latitude : Latitude range of the listing
# *longitude : Longitude range of the listing
# * room_type : Type of the listing
# * price : Price of the listing
# * minimum_nights : Minimum nights to be paid for
# * number_of_reviews : Number of reviews for the listing
# * last_review : Content of the last review
# * reviews_per_month : Average number of reviews that a listing receives per month
# * calculated_host_listings_count : Total number of listings that a host has on the Airbnb platform
# * availability_365 : The number of days in a year that a listing is available for booking on the Airbnb platform based on the listing's calendar, and reflects the number of days in the future that the listing is marked as available for booking.

# %%
# Check Unique Values for each variable.
# Airbnb_df.nunique()
for i in Airbnb_df.columns.tolist():
  print(f"No. of unique values in {i} is {Airbnb_df[i].nunique()}.")
# Out:
# No. of unique values in listing_id is 7707.
# No. of unique values in listing_url is 7707.
# No. of unique values in scrape_id is 1.
# No. of unique values in last_scraped is 2.
# No. of unique values in source is 2.
# No. of unique values in listing_name is 7229.
# No. of unique values in description is 6446.
# No. of unique values in neighborhood_overview is 3586.
# No. of unique values in picture_url is 7387.
# No. of unique values in host_id is 3351.
# No. of unique values in host_url is 3351.
# No. of unique values in host_name is 1937.
# No. of unique values in host_since is 2276.
# No. of unique values in host_location is 209.
# No. of unique values in host_about is 1878.
# No. of unique values in host_response_time is 4.
# No. of unique values in host_response_rate is 49.
# No. of unique values in host_acceptance_rate is 77.
# No. of unique values in host_is_superhost is 2.
# No. of unique values in host_thumbnail_url is 3261.
# No. of unique values in host_picture_url is 3261.
# No. of unique values in host_neighbourhood is 222.
# No. of unique values in host_listings_count is host_listings_count    62
# host_listings_count    39
# dtype: int64.
# No. of unique values in host_total_listings_count is 86.
# No. of unique values in host_verifications is 7.
# No. of unique values in host_has_profile_pic is 2.
# No. of unique values in host_identity_verified is 2.
# No. of unique values in neighbourhood is 9.
# No. of unique values in neighbourhood_cleansed is 77.
# No. of unique values in neighbourhood_group_cleansed is 0.
# No. of unique values in latitude is 6456.
# No. of unique values in longitude is 6267.
# No. of unique values in property_type is 48.
# No. of unique values in room_type is 4.
# No. of unique values in accommodates is 16.
# No. of unique values in bathrooms is 23.
# No. of unique values in bathrooms_text is 35.
# No. of unique values in bedrooms is 13.
# No. of unique values in beds is 20.
# No. of unique values in amenities is 6902.
# No. of unique values in price is 608.
# No. of unique values in minimum_nights is 48.
# No. of unique values in maximum_nights is 130.
# No. of unique values in minimum_minimum_nights is 50.
# No. of unique values in maximum_minimum_nights is 58.
# No. of unique values in minimum_maximum_nights is 114.
# No. of unique values in maximum_maximum_nights is 127.
# No. of unique values in minimum_nights_avg_ntm is 226.
# No. of unique values in maximum_nights_avg_ntm is 374.
# No. of unique values in calendar_updated is 0.
# No. of unique values in has_availability is 2.
# No. of unique values in availability_30 is 31.
# No. of unique values in availability_60 is 61.
# No. of unique values in availability_90 is 91.
# No. of unique values in availability_365 is 366.
# No. of unique values in calendar_last_scraped is 2.
# No. of unique values in total_reviews is 425.
# No. of unique values in number_of_reviews_ltm is 121.
# No. of unique values in number_of_reviews_l30d is 24.
# No. of unique values in first_review is 2197.
# No. of unique values in review_scores_rating is 119.
# No. of unique values in review_scores_accuracy is 112.
# No. of unique values in review_scores_cleanliness is 130.
# No. of unique values in review_scores_checkin is 98.
# No. of unique values in review_scores_communication is 96.
# No. of unique values in review_scores_location is 153.
# No. of unique values in review_scores_value is 127.
# No. of unique values in license is 3974.
# No. of unique values in instant_bookable is 2.
# No. of unique values in host_listings_count is host_listings_count    62
# host_listings_count    39
# dtype: int64.
# No. of unique values in calculated_host_listings_count_entire_homes is 38.
# No. of unique values in calculated_host_listings_count_private_rooms is 23.
# No. of unique values in calculated_host_listings_count_shared_rooms is 8.
# No. of unique values in reviews_per_month is 25.

# %% [markdown]
# # **Data Wrangling**

# %%
# Write your code to make your dataset analysis ready.
df = Airbnb_df.copy()  #creating copy to keep original dataset safe

# %%
#replacing null values with possible data

#categorial value like name and host name is replace with not known
df['listing_name'].fillna('not known',inplace = True)
df['host_name'].fillna('not known',inplace = True)

#replacing numerical value for reviews per month with 0 as number of review is 0 for those values
df['reviews_per_month'].fillna(0,inplace = True)

# %%
#dropping last review column as it can only provide information about the timeliness of the data being analyzed
df.drop(['listing_id'], axis=1,inplace = True)
df.isnull().sum()
# Out:
# listing_url                                     0
# scrape_id                                       0
# last_scraped                                    0
# source                                          0
# listing_name                                    0
#                                                ..
# host_listings_count                             0
# calculated_host_listings_count_entire_homes     0
# calculated_host_listings_count_private_rooms    0
# calculated_host_listings_count_shared_rooms     0
# reviews_per_month                               0
# Length: 73, dtype: int64

# %%
#calculating total count of observation where number of review is equal to 0
len(df[df['price']== 0])
# Out:
# 0

# %%
#calculating number of potential booking each can take
df['number_of_bookings'] = (df['availability_365'] / df['minimum_nights']).astype(int)
df['potential_revenue_per_year'] = df['number_of_bookings']* df['price']

# %%
#finding unique neighbourhood names and room type for each group
count = 0
for i in df.neighbourhood_group_cleansed.unique():
  count= count+1
  print(f'{count}. {i} has room type {df.room_type.unique()}')
# Out:
# 1. nan has room type ['Private room' 'Entire home/apt' 'Shared room' 'Hotel room']

# %%
# create a new DataFrame that displays the top 10 neighborhoods in the Airbnb NYC dataset based on the number of listings in each neighborhood
Top_Neighborhoods = Airbnb_df['neighbourhood'].value_counts()[:10].reset_index()

# rename the columns of the resulting DataFrame to 'Top_Neighborhoods' and 'Listing_Counts'
Top_Neighborhoods.columns = ['Top_Neighborhoods', 'Listing_Counts']

# display the resulting DataFrame
Top_Neighborhoods
# Out:
#                          Top_Neighborhoods  Listing_Counts
# 0         Chicago, Illinois, United States            5415
# 1        Oak Park, Illinois, United States               4
# 2        Chicago , Illinois, United States               3
# 3                   Chicago, United States               2
# 4    Calumet Park, Illinois, United States               1
# 5           Rogers Park, Il, United States               1
# 6  Evergreen Park, Illinois, United States               1
# 7       Riverdale, Illinois, United States               1
# 8    Elmwood Park, Illinois, United States               1

# %%
# @title Proportion of Listings by Neighborhood

# Sample data (replace with your actual data)
neighborhoods = ['Riverdale', 'Oak Park', 'Rogers Park', 'Other Neighborhood 1', 'Other Neighborhood 2']
listing_counts = [5415, 2300, 1800, 500, 100]

# Create the pie chart
plt.pie(listing_counts, labels=neighborhoods, autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Listings by Neighborhood')
_ = plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

# %%
# @title Listing_Counts

from matplotlib import pyplot as plt
Top_Neighborhoods['Listing_Counts'].plot(kind='line', figsize=(8, 4), title='Listing_Counts')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# Get the top 10 neighborhoods by listing count
top_10_neigbourhoods = Airbnb_df['neighbourhood'].value_counts().nlargest(10)

# Create a list of colors to use for the bars
colors = ['c', 'g', 'olive', 'y', 'm', 'orange', '#C0C0C0', '#800000', '#008000', '#000080']

# Create a bar plot of the top 10 neighborhoods using the specified colors
top_10_neigbourhoods.plot(kind='bar', figsize=(15, 6), color = colors)

# Set the x-axis label
plt.xlabel('Neighbourhood', fontsize=14)

# Set the y-axis label
plt.ylabel('Total Listing Counts', fontsize=14)

# Set the title of the plot
plt.title('Listings by Top Neighborhoods in NYC', fontsize=15)
# Out:
# Text(0.5, 1.0, 'Listings by Top Neighborhoods in NYC')

# %%
# create a new DataFrame that displays the top 10 hosts in the Airbnb NYC dataset based on the number of listings each host has
top_10_hosts = Airbnb_df['host_name'].value_counts()[:10].reset_index()

# rename the columns of the resulting DataFrame to 'host_name' and 'Total_listings'
top_10_hosts.columns = ['host_name', 'Total_listings']

# display the resulting DataFrame
top_10_hosts
# Out:
#     host_name  Total_listings
# 0  Blueground             555
# 1       Level              82
# 2       Milan              77
# 3        Ella              72
# 4        Matt              67
# 5       Ralph              65
# 6       David              62
# 7         Joe              60
# 8     Michael              58
# 9      Cloud9              57

# %%
# Get the top 10 hosts by listing count
top_hosts = Airbnb_df['host_name'].value_counts()[:10]

# Create a bar plot of the top 10 hosts
top_hosts.plot(kind='bar', color='peru', figsize=(18, 7))

# Set the x-axis label
plt.xlabel('top10_hosts', fontsize=14)

# Set the y-axis label
plt.ylabel('total_NYC_listings', fontsize=14)

# Set the title of the plot
plt.title('top 10 hosts on the basis of no of listings in entire NYC!', fontsize=15)
# Out:
# Text(0.5, 1.0, 'top 10 hosts on the basis of no of listings in entire NYC!')

# %%
 #Total Counts Of Each Room Type


# create a new DataFrame that displays the number of listings of each room type in the Airbnb NYC dataset
top_room_type = Airbnb_df['room_type'].value_counts().reset_index()

# rename the columns of the resulting DataFrame to 'Room_Type' and 'Total_counts'
top_room_type.columns = ['Room_Type', 'Total_counts']

# display the resulting DataFrame
top_room_type
# Out:
#          Room_Type  Total_counts
# 0  Entire home/apt          5924
# 1     Private room          1674
# 2      Shared room            72
# 3       Hotel room            37

# %%
# @title Room_Type

from matplotlib import pyplot as plt
import seaborn as sns
top_room_type.groupby('Room_Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Set the figure size
plt.figure(figsize=(10, 6))

# Get the room type counts
room_type_counts = Airbnb_df['room_type'].value_counts()

# Set the labels and sizes for the pie chart
labels = room_type_counts.index
sizes = room_type_counts.values

# Create the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# Add a legend to the chart
plt.legend(title='Room Type', bbox_to_anchor=(0.8, 0, 0.5, 1), fontsize='12')

# Show the plot
plt.show()

# %%
#Stay Requirement counts by Minimum Nights using Bar chart


# Group the DataFrame by the minimum_nights column and count the number of rows in each group
min_nights_count = Airbnb_df.groupby('minimum_nights').size().reset_index(name = 'count')

# Sort the resulting DataFrame in descending order by the count column
min_nights_count = min_nights_count.sort_values('count', ascending=False)

# Select the top 10 rows
min_nights_count = min_nights_count.head(15)

# Reset the index
min_nights_count = min_nights_count.reset_index(drop=True)

# Display the resulting DataFrame
min_nights_count
# Out:
#     minimum_nights  count
# 0               32   2529
# 1                2   2293
# 2                1   1761
# 3                3    615
# 4                4     80
# 5                5     74
# 6               30     37
# 7                7     36
# 8               33     32
# 9               28     31
# 10              60     26
# 11              10     25
# 12              90     21
# 13             360     19
# 14               6     14

# %%
# @title minimum_nights

from matplotlib import pyplot as plt
min_nights_count['minimum_nights'].plot(kind='line', figsize=(8, 4), title='minimum_nights')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
 #most reviewed room type per month in neighbourhood groups


# create a figure with a default size of (10, 8)
f, ax = plt.subplots(figsize=(10, 8))

# create a stripplot that displays the number of reviews per month for each room type in the Airbnb NYC dataset
ax = sns.stripplot(x='room_type', y='reviews_per_month', hue='neighbourhood_group_cleansed', dodge=True, data=Airbnb_df, palette='Set1')

# set the title of the plot
ax.set_title('Most Reviewed room_types in each Neighbourhood Groups', fontsize='14')
# Out:
# Text(0.5, 1.0, 'Most Reviewed room_types in each Neighbourhood Groups')

# %%
# Let's observe the type of room_types

# set the default figure size for the seaborn library
sns.set(rc={"figure.figsize": (10, 8)})

# create a scatter plot that displays the longitude and latitude of the listings in the Airbnb NYC dataset with room_types.
ax = sns.scatterplot(x=Airbnb_df.longitude, y=Airbnb_df.latitude, hue=Airbnb_df.room_type, palette='muted')

# set the title of the plot
ax.set_title('Distribution of type of rooms across NYC', fontsize='14')
# Out:
# Text(0.5, 1.0, 'Distribution of type of rooms across NYC')

# %%
# Let's have an idea of the price variations in neighborhood_groups

# create a scatter plot that displays the longitude and latitude of the listings in the Airbnb  dataset, with the color of each point indicating the price of the listing
lat_long = Airbnb_df.plot(kind='scatter', x='longitude', y='latitude', label='price_variations', cmap='jet', colorbar=True, alpha=0.4, figsize=(10, 8))


# add a legend to the plot
lat_long.legend()

# %%
#from IPython.display import Image

# Replace "path/to/photo.jpg" with the actual path to your photo on Google Drive
#Image("path/to/photo.jpg", resize=(600, 400))  # Set the width to 600 pixels and the height to 400 pixels

# %% [markdown]
# ![chicago.jpg](data:image/jpeg;base64,...)
